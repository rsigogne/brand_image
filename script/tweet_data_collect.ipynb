# %% [markdown]
# # Simple way to collect twitter data
#
# Twitter account:
# - mail: renault.raphael2.com
# - password: renault-oao (both twitter & gmail)
#
# My API key:
# Qvv4f5bG3QsZOEluHOp27cXwN
#
# My API secret:
# No5y6jzLEKD1ZQuopvOj6FrAzhPUPggYHJY4ugRCA2J7rWGm4j
#
# My access_token:
# 971754780749172736-N7fMVHEJsi7fsBZITGt4Qv5TLp6n2eS
#
# My access_secret:
# LuHZoRFZeHlRuHyrdxMZiMWLWItpwroZjNtNAkOyeve87

# %%
# Import the necessary package to process data in JSON format
try:
    import json
except ImportError:
    import simplejson as json

# Import the necessary methods from "twitter" library
from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream, application

# Variables that contains the user credentials to access Twitter API 
ACCESS_TOKEN = "971754780749172736-N7fMVHEJsi7fsBZITGt4Qv5TLp6n2eS"
ACCESS_SECRET = "LuHZoRFZeHlRuHyrdxMZiMWLWItpwroZjNtNAkOyeve87"
CONSUMER_KEY = "Qvv4f5bG3QsZOEluHOp27cXwN"
CONSUMER_SECRET = "No5y6jzLEKD1ZQuopvOj6FrAzhPUPggYHJY4ugRCA2J7rWGm4j"

oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# Initiate the connection to Twitter Streaming API
twitter_stream = TwitterStream(auth=oauth)

# Get a sample of the public data following through Twitter
iterator = twitter_stream.statuses.filter(track=["Renault", "renault"], language="fr")
# iterator = twitter_stream.statuses.sample()

# Print each tweet in the stream to the screen 
# Here we set it to stop after getting 1000 tweets. 
# You don't have to set it to stop, but can continue running 
# the Twitter API to collect data for days or even longer. 
tweet_count = 1000
for tweet in iterator:
    tweet_count -= 1
    # Twitter Python Tool wraps the data returned by Twitter 
    # as a TwitterDictResponse object.
    # We convert it back to the JSON format to print/score
    # print(json.dumps(tweet))
    
    # The command below will do pretty printing for JSON data, try it out
    print(json.dumps(tweet, indent=4))
       
    if tweet_count <= 0:
        break
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/twitter/stream.py in handle_stream_response(req, uri, arg_data, block, timeout, heartbeat_timeout)
#     210     try:
# --> 211         handle = urllib_request.urlopen(req,)
#     212     except urllib_error.HTTPError as e:
#
# ~/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# ~/anaconda3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# ~/anaconda3/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 401: Authorization Required
#
# During handling of the above exception, another exception occurred:
#
# TwitterHTTPError                          Traceback (most recent call last)
# <ipython-input-5-e18c2def2bad> in <module>()
#      20
#      21 # Get a sample of the public data following through Twitter
# ---> 22 iterator = twitter_stream.statuses.sample()
#      23
#      24 # Print each tweet in the stream to the screen
#
# ~/anaconda3/lib/python3.6/site-packages/twitter/api.py in __call__(self, **kwargs)
#     332             return self._handle_response_with_retry(req, uri, arg_data, _timeout)
#     333         else:
# --> 334             return self._handle_response(req, uri, arg_data, _timeout)
#     335
#     336     def _handle_response(self, req, uri, arg_data, _timeout=None):
#
# ~/anaconda3/lib/python3.6/site-packages/twitter/stream.py in _handle_response(self, req, uri, arg_data, _timeout)
#     286                 return handle_stream_response(
#     287                     req, uri, arg_data, block,
# --> 288                     _timeout or timeout, heartbeat_timeout)
#     289
#     290         TwitterCall.__init__(
#
# ~/anaconda3/lib/python3.6/site-packages/twitter/stream.py in handle_stream_response(req, uri, arg_data, block, timeout, heartbeat_timeout)
#     211         handle = urllib_request.urlopen(req,)
#     212     except urllib_error.HTTPError as e:
# --> 213         raise TwitterHTTPError(e, uri, 'json', arg_data)
#     214     return iter(TwitterJSONIter(handle, uri, arg_data, block, timeout, heartbeat_timeout))
#     215
#
# TwitterHTTPError: Twitter sent status 401 for URL: 1.1/statuses/sample.json using parameters: (oauth_consumer_key=YOUR%20API%20KEY&oauth_nonce=1347249711498429065&oauth_signature_method=HMAC-SHA1&oauth_timestamp=1520521093&oauth_token=YOUR%20ACCESS%20TOKEN%22&oauth_version=1.0&oauth_signature=dfAXrRWOYv%2FQ4BRjOrOFroncJt4%3D)
# details: <html>\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n<title>Error 401 Unauthorized</title>
# </head>
# <body>
# <h2>HTTP ERROR: 401</h2>
# <p>Problem accessing '/1.1/statuses/sample.json?oauth_consumer_key=YOUR%20API%20KEY&amp;oauth_nonce=1347249711498429065&amp;oauth_signature_method=HMAC-SHA1&amp;oauth_timestamp=1520521093&amp;oauth_token=YOUR%20ACCESS%20TOKEN%22&amp;oauth_version=1.0&amp;oauth_signature=dfAXrRWOYv%2FQ4BRjOrOFroncJt4%3D'. Reason:
# <pre>    Unauthorized</pre>
# </body>
# </html>

# %%
# Import the necessary package to process data in JSON format
try:
    import json
except ImportError:
    import simplejson as json

# Import the necessary methods from "twitter" library
from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream

# Variables that contains the user credentials to access Twitter API 
ACCESS_TOKEN = "971754780749172736-N7fMVHEJsi7fsBZITGt4Qv5TLp6n2eS"
ACCESS_SECRET = "LuHZoRFZeHlRuHyrdxMZiMWLWItpwroZjNtNAkOyeve87"
CONSUMER_KEY = "Qvv4f5bG3QsZOEluHOp27cXwN"
CONSUMER_SECRET = "No5y6jzLEKD1ZQuopvOj6FrAzhPUPggYHJY4ugRCA2J7rWGm4j"

oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# Initiate the connection to Twitter Streaming API
twitter = Twitter(auth=oauth)

twitter.application.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '971754780749172736-N7fMVHEJsi7fsBZITGt4Qv5TLp6n2eS'},
#  'resources': {'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1520591241}},
#   'account_activity': {'/account_activity/all/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1520591241},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1520591241},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1520591241},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 179,
#     'reset': 1520591241}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241}},
#   'blocks': {'/blocks/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/blocks/list': {'limit': 15, 'remaining': 15, 'reset': 1520591241}},
#   'business_experience': {'/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241},
#    '/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241}},
#   'collections': {'/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1520591241},
#    '/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1520591241},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1520591241}},
#   'contacts': {'/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1520591241},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1520591241},
#    '/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1520591241},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1520591241},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1520591241}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241}},
#   'direct_messages': {'/direct_messages': {'limit': 300,
#     'remaining': 300,
#     'reset': 1520591241},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1520591241},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1520591241},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1520591241},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1520591241},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1520591241},
#    '/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1520591241},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1520591241},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1520591241},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1520591241},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241}},
#   'drafts': {'/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241},
#    '/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1520591241}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1520591241}},
#   'feedback': {'/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1520591241},
#    '/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1520591241}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1520591241}},
#   'friendships': {'/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1520591241},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1520591241}},
#   'geo': {'/geo/id/:place_id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1520591241},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/geo/similar_places': {'limit': 15, 'remaining': 15, 'reset': 1520591241}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1520591241}},
#   'help': {'/help/configuration': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1520591241}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1520591241}},
#   'lists': {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1520591241},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1520591241},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1520591241},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1520591241},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1520591241},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/lists/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1520591241}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1520591241}},
#   'moments': {'/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1520591241},
#    '/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1520591241}},
#   'mutes': {'/mutes/users/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/mutes/users/list': {'limit': 15, 'remaining': 15, 'reset': 1520591241}},
#   'safety': {'/safety/detection_feedback': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1520591241}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1520591241}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/saved_searches/list': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241}},
#   'statuses': {'/statuses/friends': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1520591241},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1520591241},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1520591241},
#    '/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1520591241},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1520591241},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1520591241},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1520591241},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1520591241}},
#   'trends': {'/trends/available': {'limit': 75,
#     'remaining': 75,
#     'reset': 1520591241},
#    '/trends/closest': {'limit': 75, 'remaining': 75, 'reset': 1520591241},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1520591241}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241}},
#   'tweets': {'/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1520591241},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1520591241}},
#   'users': {'/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1520591241},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1520591241},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1520591241},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1520591241},
#    '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1520591241},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1520591241},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1520591241},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241}},
#   'webhooks': {'/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241},
#    '/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520591241}}}}

# %%
import twitter

# %%
twitter.
